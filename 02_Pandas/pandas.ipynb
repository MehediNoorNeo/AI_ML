# %%
import pandas as pd

# %%
s_info = {
    "Name" : ["Mehedi", "Mamun", "Sajan", "Reaz"],
    "CGPA" : ["3.44", "3.53", "3.53", "3.66"]
} 
df = pd.DataFrame(s_info)
df
# Out:
#      Name  CGPA
# 0  Mehedi  3.44
# 1   Mamun  3.53
# 2   Sajan  3.53
# 3    Reaz  3.66
